# %%
from pathlib import Path
while not (Path.cwd() / '.git').exists():
    # %cd ..
# Out:
# /home/matthew/study/grab-voc-triage

# %%
import pandas as pd
from src.preprocessing.transform import length_filter

# %%
df = pd.read_csv('data/raw/grab_reviews.csv')
df
# Out:
#              userName  score                   at  \
# 0     Pengguna Google      1  2026-09-03 09:16:13
# 1     Pengguna Google      5  2026-09-03 09:16:06
# 2     Pengguna Google      1  2026-09-03 09:11:34
# 3     Pengguna Google      5  2026-09-03 08:57:58
# 4     Pengguna Google      5  2026-09-03 08:32:12
# ...               ...    ...                  ...
# 9995    Hesti Aprilia      1  2026-04-15 21:04:13
# 9996    Hearty Tandur      4  2026-04-15 21:02:52
# 9997        Ades Arka      5  2026-04-15 20:52:16
# 9998        Lisa Aini      5  2026-04-15 20:51:24
# 9999     Black_rabbit      1  2026-04-15 20:42:33
#
#                                                 content
# 0     barang ketinggalan, udah minta bantu bantuan p...
# 1                 Drivernya ramah dan jalannya berhati2
# 2                                 turunin harga grab !.
# 3                                           GOOD JOB👍👍👍
# 4                                           Sangat puas
# ...

# %%
length_filter(df)['score'].value_counts()
# Out:
# score
# 1    1716
# 5    1176
# 2     307
# 3     293
# 4     183
# Name: count, dtype: int64
